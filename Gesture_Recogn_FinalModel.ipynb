# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started. Once you have completed the code you can download the notebook for making a submission.

# %%
import numpy as np
import os
from imageio import imread
from skimage.transform import resize
import datetime
import os
from sys import getsizeof
import abc

# %%
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from tensorflow import keras
import tensorflow as tf
tf.random.set_seed(30)
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %% [markdown]
# **data path: datasets/Project_data**

# %%
train_doc = np.random.permutation(open('datasets/Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('datasets/Project_data/val.csv').readlines())
batch_size = 50 #experiment with the batch size

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
import abc
class ModelBuilder(metaclass= abc.ABCMeta):
    # initialisng the path where project data resides
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
    # initialising the image properties    
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
    # initialising the batch size, frames to sample and the no. of epochs
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=50,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
    # MOST IMPORTANT PART HERE - The generator function        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx):
                #performing image reading and resizing
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=resize(image,(self.image_height,self.image_width,3))
            
                #normalizing the images
                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    # cropping the images to have the targeted gestures and remove the noise from the images.
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=resize(cropped,(self.image_height,self.image_width,3))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (image_resized[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=False, mode='auto', period=1)
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        
        earlystop = EarlyStopping( monitor="val_loss", min_delta=0,patience=10,verbose=1)
        callbacks_list = [checkpoint, LR, earlystop]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
curr_dt_time = datetime.datetime.now()
train_path = 'datasets/Project_data/train'
val_path = 'datasets/Project_data/val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 20
# choose the number of epochs
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 20

# %% [markdown]
# ## Model
# Here you make the model using different functionalities that Keras provides. Remember to use `Conv3D` and `MaxPooling3D` and not `Conv2D` and `Maxpooling2D` for a 3D convolution model. You would want to use `TimeDistributed` while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, GRU, Dropout, Flatten, BatchNormalization, Activation, Conv3D, MaxPooling3D
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras import optimizers

#write your model here

class ModelConv3D1(ModelBuilder):
    
    def define_model(self):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(128,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))

        model.add(Dense(64,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()  #write your optimizer
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %%
project_folder = 'datasets/Project_data'

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=40,num_epochs=1)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d (Conv3D)              (None, 30, 160, 160, 16)  1312
# _________________________________________________________________
# activation (Activation)      (None, 30, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d (MaxPooling3D) (None, 15, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_1 (Conv3D)            (None, 15, 80, 80, 32)    4128
# _________________________________________________________________
# activation_1 (Activation)    (None, 15, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 15, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 7, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 7, 40, 40, 64)     16448
# _________________________________________________________________
# activation_2 (Activation)    (None, 7, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 7, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 3, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 3, 20, 20, 128)    65664
# _________________________________________________________________
# activation_3 (Activation)    (None, 3, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 3, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               1638528
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 1,736,389
# Trainable params: 1,735,525
# Non-trainable params: 864
# _________________________________________________________________

# %% [markdown]
# Let us create the `train_generator` and the `val_generator` which will be used in `.fit_generator`.

# %%
train_generator = ModelBuilder.generator(train_path, train_doc, batch_size)
val_generator = ModelBuilder.generator(val_path, val_doc, batch_size)

# %%
test_generator=ModelConv3D1()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=1)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,15,:,:,:])   
axes[1].imshow(batch_data[3,15,:,:,:])

# %%
print("Memory util is {} Gigs". format(getsizeof(np.zeros((40,16,30,160,160)))/(1024*1024*1024)))
# Out:
# Memory util is 3.662109524011612 Gigs

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)
        
filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto',save_freq = num_epochs)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
# write the REducelronplateau code here
callbacks_list = [checkpoint, LR]

# %% [markdown]
# The `steps_per_epoch` and `validation_steps` are used by `fit` method to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Let us now fit the model. This will start training the model and with the help of the checkpoints, you'll be able to save the model at the end of each epoch.

# %% [markdown]
# ## Model #1
# #### Base Model - Batch Size = 40 and No. of Epochs = 15

# %%
class ModelConv3D1(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=20,batch_size=40,num_epochs=15)
conv_3d1_model=conv_3d1.define_model()
conv_3d1_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_4 (Conv3D)            (None, 20, 160, 160, 16)  1312
# _________________________________________________________________
# activation_4 (Activation)    (None, 20, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 20, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 10, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_5 (Conv3D)            (None, 10, 80, 80, 32)    13856
# _________________________________________________________________
# activation_5 (Activation)    (None, 10, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 10, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 5, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 5, 40, 40, 64)     55360
# _________________________________________________________________
# activation_6 (Activation)    (None, 5, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 5, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 2, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 2, 20, 20, 128)    221312
# _________________________________________________________________
# activation_7 (Activation)    (None, 2, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 2, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_7 (MaxPooling3 (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                819264
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                4160
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 1,117,061
# Trainable params: 1,116,325
# Non-trainable params: 736
# _________________________________________________________________

# %%
print("Total Params:", conv_3d1_model.count_params())
history_model1 = conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1117061
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:From <ipython-input-7-1795af00ad33>:128: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/15
# 17/17 [==============================] - ETA: 0s - loss: 1.4009 - categorical_accuracy: 0.4540
# Epoch 00001: val_loss improved from inf to 1.66510, saving model to model_init_2021-08-0205_35_57.224452/model-00001-1.40087-0.45400-1.66510-0.31000.h5
# 17/17 [==============================] - 111s 7s/step - loss: 1.4009 - categorical_accuracy: 0.4540 - val_loss: 1.6651 - val_categorical_accuracy: 0.3100
# Epoch 2/15
# 17/17 [==============================] - ETA: 0s - loss: 0.8568 - categorical_accuracy: 0.6742
# Epoch 00002: val_loss did not improve from 1.66510
# 17/17 [==============================] - 114s 7s/step - loss: 0.8568 - categorical_accuracy: 0.6742 - val_loss: 2.3051 - val_categorical_accuracy: 0.1800
# Epoch 3/15
# 17/17 [==============================] - ETA: 0s - loss: 0.5538 - categorical_accuracy: 0.7903
# Epoch 00003: val_loss did not improve from 1.66510
# 17/17 [==============================] - 112s 7s/step - loss: 0.5538 - categorical_accuracy: 0.7903 - val_loss: 2.2650 - val_categorical_accuracy: 0.3100
# Epoch 4/15
# 17/17 [==============================] - ETA: 0s - loss: 0.3761 - categorical_accuracy: 0.8627
# Epoch 00004: val_loss did not improve from 1.66510
# 17/17 [==============================] - 117s 7s/step - loss: 0.3761 - categorical_accuracy: 0.8627 - val_loss: 2.8812 - val_categorical_accuracy: 0.2100
# Epoch 5/15
# 17/17 [==============================] - ETA: 0s - loss: 0.2324 - categorical_accuracy: 0.9216
# Epoch 00005: val_loss did not improve from 1.66510
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 17/17 [==============================] - 117s 7s/step - loss: 0.2324 - categorical_accuracy: 0.9216 - val_loss: 3.0830 - val_categorical_accuracy: 0.2600
# Epoch 6/15
# 17/17 [==============================] - ETA: 0s - loss: 0.1679 - categorical_accuracy: 0.9593
# Epoch 00006: val_loss did not improve from 1.66510
# 17/17 [==============================] - 113s 7s/step - loss: 0.1679 - categorical_accuracy: 0.9593 - val_loss: 3.3246 - val_categorical_accuracy: 0.1600
# Epoch 7/15
# 17/17 [==============================] - ETA: 0s - loss: 0.1530 - categorical_accuracy: 0.9578
# Epoch 00007: val_loss did not improve from 1.66510
# 17/17 [==============================] - 115s 7s/step - loss: 0.1530 - categorical_accuracy: 0.9578 - val_loss: 3.2447 - val_categorical_accuracy: 0.2100
# Epoch 8/15
# 17/17 [==============================] - ETA: 0s - loss: 0.1042 - categorical_accuracy: 0.9864
# Epoch 00008: val_loss did not improve from 1.66510
# 17/17 [==============================] - 114s 7s/step - loss: 0.1042 - categorical_accuracy: 0.9864 - val_loss: 3.4264 - val_categorical_accuracy: 0.2000
# Epoch 9/15
# 17/17 [==============================] - ETA: 0s - loss: 0.1043 - categorical_accuracy: 0.9834
# Epoch 00009: val_loss did not improve from 1.66510
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 17/17 [==============================] - 111s 7s/step - loss: 0.1043 - categorical_accuracy: 0.9834 - val_loss: 3.8378 - val_categorical_accuracy: 0.2000
# Epoch 10/15
# 17/17 [==============================] - ETA: 0s - loss: 0.0885 - categorical_accuracy: 0.9879
# Epoch 00010: val_loss did not improve from 1.66510
# 17/17 [==============================] - 115s 7s/step - loss: 0.0885 - categorical_accuracy: 0.9879 - val_loss: 3.7741 - val_categorical_accuracy: 0.2100
# Epoch 11/15
# 17/17 [==============================] - ETA: 0s - loss: 0.0736 - categorical_accuracy: 0.9925
# Epoch 00011: val_loss did not improve from 1.66510
# 17/17 [==============================] - 117s 7s/step - loss: 0.0736 - categorical_accuracy: 0.9925 - val_loss: 3.7192 - val_categorical_accuracy: 0.2300
# Epoch 00011: early stopping

# %%
# function to plot the training/validation accuracies/losses.

def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].legend(['loss','val_loss'])

    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %%
plot(history_model1)

# %% [markdown]
# ### Observations : Clearly Model 1 is overfitting

# %% [markdown]
# ## Model #2
# #### Adding dropout layers - Resr keeping constant as Batch Size = 40 and No. of Epochs = 15

# %%
conv_3d2=ModelConv3D1()
conv_3d2.initialize_path(project_folder)
conv_3d2.initialize_image_properties(image_height=160,image_width=160)
conv_3d2.initialize_hyperparams(frames_to_sample=20,batch_size=40,num_epochs=15)
conv_3d2_model=conv_3d2.define_model(dense_neurons=256,dropout=0.5)
conv_3d2_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_8 (Conv3D)            (None, 20, 160, 160, 16)  1312
# _________________________________________________________________
# activation_8 (Activation)    (None, 20, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 20, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d_8 (MaxPooling3 (None, 10, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_9 (Conv3D)            (None, 10, 80, 80, 32)    13856
# _________________________________________________________________
# activation_9 (Activation)    (None, 10, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 10, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_9 (MaxPooling3 (None, 5, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_10 (Conv3D)           (None, 5, 40, 40, 64)     55360
# _________________________________________________________________
# activation_10 (Activation)   (None, 5, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 5, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_10 (MaxPooling (None, 2, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_11 (Conv3D)           (None, 2, 20, 20, 128)    221312
# _________________________________________________________________
# activation_11 (Activation)   (None, 2, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 2, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_11 (MaxPooling (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               3277056
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 5)                 1285
# =================================================================
# Total params: 3,638,981
# Trainable params: 3,637,477
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d2_model.count_params())
history_model2=conv_3d2.train_model(conv_3d2_model)
# Out:
# Total Params: 3638981
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/15
# 17/17 [==============================] - ETA: 0s - loss: 1.6920 - categorical_accuracy: 0.4374
# Epoch 00001: val_loss improved from inf to 3.42466, saving model to model_init_2021-08-0207_18_46.063265/model-00001-1.69195-0.43741-3.42466-0.23000.h5
# 17/17 [==============================] - 160s 9s/step - loss: 1.6920 - categorical_accuracy: 0.4374 - val_loss: 3.4247 - val_categorical_accuracy: 0.2300
# Epoch 2/15
# 17/17 [==============================] - ETA: 0s - loss: 1.1468 - categorical_accuracy: 0.6063
# Epoch 00002: val_loss improved from 3.42466 to 2.88361, saving model to model_init_2021-08-0207_18_46.063265/model-00002-1.14678-0.60633-2.88361-0.24000.h5
# 17/17 [==============================] - 160s 9s/step - loss: 1.1468 - categorical_accuracy: 0.6063 - val_loss: 2.8836 - val_categorical_accuracy: 0.2400
# Epoch 3/15
# 17/17 [==============================] - ETA: 0s - loss: 0.8039 - categorical_accuracy: 0.6953
# Epoch 00003: val_loss did not improve from 2.88361
# 17/17 [==============================] - 149s 9s/step - loss: 0.8039 - categorical_accuracy: 0.6953 - val_loss: 4.7666 - val_categorical_accuracy: 0.2100
# Epoch 4/15
# 17/17 [==============================] - ETA: 0s - loss: 0.5604 - categorical_accuracy: 0.7903
# Epoch 00004: val_loss did not improve from 2.88361
# 17/17 [==============================] - 157s 9s/step - loss: 0.5604 - categorical_accuracy: 0.7903 - val_loss: 6.5323 - val_categorical_accuracy: 0.2100
# Epoch 5/15
# 17/17 [==============================] - ETA: 0s - loss: 0.4076 - categorical_accuracy: 0.8567
# Epoch 00005: val_loss did not improve from 2.88361
# 17/17 [==============================] - 161s 9s/step - loss: 0.4076 - categorical_accuracy: 0.8567 - val_loss: 7.1901 - val_categorical_accuracy: 0.2000
# Epoch 6/15
# 17/17 [==============================] - ETA: 0s - loss: 0.3000 - categorical_accuracy: 0.8884
# Epoch 00006: val_loss did not improve from 2.88361
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 17/17 [==============================] - 151s 9s/step - loss: 0.3000 - categorical_accuracy: 0.8884 - val_loss: 8.5383 - val_categorical_accuracy: 0.2200
# Epoch 7/15
# 17/17 [==============================] - ETA: 0s - loss: 0.2268 - categorical_accuracy: 0.9155
# Epoch 00007: val_loss did not improve from 2.88361
# 17/17 [==============================] - 154s 9s/step - loss: 0.2268 - categorical_accuracy: 0.9155 - val_loss: 8.8862 - val_categorical_accuracy: 0.2100
# Epoch 8/15
# 17/17 [==============================] - ETA: 0s - loss: 0.1739 - categorical_accuracy: 0.9397
# Epoch 00008: val_loss did not improve from 2.88361
# 17/17 [==============================] - 150s 9s/step - loss: 0.1739 - categorical_accuracy: 0.9397 - val_loss: 8.8875 - val_categorical_accuracy: 0.1900
# Epoch 9/15
# 17/17 [==============================] - ETA: 0s - loss: 0.1653 - categorical_accuracy: 0.9427
# Epoch 00009: val_loss did not improve from 2.88361
# 17/17 [==============================] - 160s 9s/step - loss: 0.1653 - categorical_accuracy: 0.9427 - val_loss: 9.4938 - val_categorical_accuracy: 0.2500
# Epoch 10/15
# 17/17 [==============================] - ETA: 0s - loss: 0.1519 - categorical_accuracy: 0.9457
# Epoch 00010: val_loss did not improve from 2.88361
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 17/17 [==============================] - 149s 9s/step - loss: 0.1519 - categorical_accuracy: 0.9457 - val_loss: 9.8309 - val_categorical_accuracy: 0.2100
# Epoch 11/15
# 17/17 [==============================] - ETA: 0s - loss: 0.0981 - categorical_accuracy: 0.9668
# Epoch 00011: val_loss did not improve from 2.88361
# 17/17 [==============================] - 160s 9s/step - loss: 0.0981 - categorical_accuracy: 0.9668 - val_loss: 9.7401 - val_categorical_accuracy: 0.2100
# Epoch 12/15
# 17/17 [==============================] - ETA: 0s - loss: 0.0749 - categorical_accuracy: 0.9789
# Epoch 00012: val_loss did not improve from 2.88361
# 17/17 [==============================] - 153s 9s/step - loss: 0.0749 - categorical_accuracy: 0.9789 - val_loss: 10.0432 - val_categorical_accuracy: 0.2100
# Epoch 00012: early stopping

# %%
plot(history_model2)

# %% [markdown]
# ### val_loss did not improve from 2.88361 so earlystopping stops the epoch automatically. Last epoch stop on 12/15!!

# %% [markdown]
# ## Model 3
# #### Reduce filter size to (2,2,2) and image res to 120 x 120, - Batch Size = 30 and No. of Epochs = 25

# %%
class ModelConv3D3(ModelBuilder):
    
    def define_model(self,filtersize=(3,3,3),dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, filtersize, padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, filtersize, padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))


        model.add(Dense(self.num_classes,activation='softmax'))
        
        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d3=ModelConv3D3()
conv_3d3.initialize_path(project_folder)
conv_3d3.initialize_image_properties(image_height=120,image_width=120)
conv_3d3.initialize_hyperparams(frames_to_sample=16,batch_size=30,num_epochs=25)
conv_3d3_model=conv_3d3.define_model(filtersize=(2,2,2),dense_neurons=256,dropout=0.5)
conv_3d3_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_12 (Conv3D)           (None, 16, 120, 120, 16)  400
# _________________________________________________________________
# activation_12 (Activation)   (None, 16, 120, 120, 16)  0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 16, 120, 120, 16)  64
# _________________________________________________________________
# max_pooling3d_12 (MaxPooling (None, 8, 60, 60, 16)     0
# _________________________________________________________________
# conv3d_13 (Conv3D)           (None, 8, 60, 60, 32)     4128
# _________________________________________________________________
# activation_13 (Activation)   (None, 8, 60, 60, 32)     0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 8, 60, 60, 32)     128
# _________________________________________________________________
# max_pooling3d_13 (MaxPooling (None, 4, 30, 30, 32)     0
# _________________________________________________________________
# conv3d_14 (Conv3D)           (None, 4, 30, 30, 64)     16448
# _________________________________________________________________
# activation_14 (Activation)   (None, 4, 30, 30, 64)     0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 4, 30, 30, 64)     256
# _________________________________________________________________
# max_pooling3d_14 (MaxPooling (None, 2, 15, 15, 64)     0
# _________________________________________________________________
# conv3d_15 (Conv3D)           (None, 2, 15, 15, 128)    65664
# _________________________________________________________________
# activation_15 (Activation)   (None, 2, 15, 15, 128)    0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 2, 15, 15, 128)    512
# _________________________________________________________________
# max_pooling3d_15 (MaxPooling (None, 1, 7, 7, 128)      0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 256)               1605888
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 256)               65792
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 5)                 1285
# =================================================================
# Total params: 1,762,613
# Trainable params: 1,761,109
# Non-trainable params: 1,504
# _________________________________________________________________

# %%
print("Total Params:", conv_3d3_model.count_params())
history_model3=conv_3d3.train_model(conv_3d3_model,augment_data=True)
# Out:
# Total Params: 1762613
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/25
# 23/23 [==============================] - ETA: 0s - loss: 2.1974 - categorical_accuracy: 0.3265
# Epoch 00001: val_loss improved from inf to 1.85794, saving model to model_init_2021-08-0206_42_35.323119/model-00001-2.19739-0.32655-1.85794-0.16000.h5
# 23/23 [==============================] - 163s 7s/step - loss: 2.1974 - categorical_accuracy: 0.3265 - val_loss: 1.8579 - val_categorical_accuracy: 0.1600
# Epoch 2/25
# 23/23 [==============================] - ETA: 0s - loss: 1.4952 - categorical_accuracy: 0.4842
# Epoch 00002: val_loss did not improve from 1.85794
# 23/23 [==============================] - 155s 7s/step - loss: 1.4952 - categorical_accuracy: 0.4842 - val_loss: 2.8017 - val_categorical_accuracy: 0.1300
# Epoch 3/25
# 23/23 [==============================] - ETA: 0s - loss: 1.1818 - categorical_accuracy: 0.5769
# Epoch 00003: val_loss did not improve from 1.85794
# 23/23 [==============================] - 168s 7s/step - loss: 1.1818 - categorical_accuracy: 0.5769 - val_loss: 4.0966 - val_categorical_accuracy: 0.1400
# Epoch 4/25
# 23/23 [==============================] - ETA: 0s - loss: 1.1155 - categorical_accuracy: 0.6192
# Epoch 00004: val_loss did not improve from 1.85794
# 23/23 [==============================] - 180s 8s/step - loss: 1.1155 - categorical_accuracy: 0.6192 - val_loss: 5.2380 - val_categorical_accuracy: 0.2100
# Epoch 5/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8685 - categorical_accuracy: 0.6704
# Epoch 00005: val_loss did not improve from 1.85794
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 23/23 [==============================] - 190s 8s/step - loss: 0.8685 - categorical_accuracy: 0.6704 - val_loss: 6.4303 - val_categorical_accuracy: 0.1600
# Epoch 6/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8853 - categorical_accuracy: 0.6953
# Epoch 00006: val_loss did not improve from 1.85794
# 23/23 [==============================] - 194s 8s/step - loss: 0.8853 - categorical_accuracy: 0.6953 - val_loss: 7.2693 - val_categorical_accuracy: 0.1600
# Epoch 7/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8305 - categorical_accuracy: 0.7029
# Epoch 00007: val_loss did not improve from 1.85794
# 23/23 [==============================] - 197s 9s/step - loss: 0.8305 - categorical_accuracy: 0.7029 - val_loss: 7.5412 - val_categorical_accuracy: 0.1800
# Epoch 8/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7673 - categorical_accuracy: 0.7247
# Epoch 00008: val_loss did not improve from 1.85794
# 23/23 [==============================] - 189s 8s/step - loss: 0.7673 - categorical_accuracy: 0.7247 - val_loss: 7.9600 - val_categorical_accuracy: 0.1600
# Epoch 9/25
# 23/23 [==============================] - ETA: 0s - loss: 0.8140 - categorical_accuracy: 0.7014
# Epoch 00009: val_loss did not improve from 1.85794
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 23/23 [==============================] - 188s 8s/step - loss: 0.8140 - categorical_accuracy: 0.7014 - val_loss: 8.0595 - val_categorical_accuracy: 0.1700
# Epoch 10/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7227 - categorical_accuracy: 0.7443
# Epoch 00010: val_loss did not improve from 1.85794
# 23/23 [==============================] - 162s 7s/step - loss: 0.7227 - categorical_accuracy: 0.7443 - val_loss: 8.0354 - val_categorical_accuracy: 0.1600
# Epoch 11/25
# 23/23 [==============================] - ETA: 0s - loss: 0.7866 - categorical_accuracy: 0.7202
# Epoch 00011: val_loss did not improve from 1.85794
# 23/23 [==============================] - 162s 7s/step - loss: 0.7866 - categorical_accuracy: 0.7202 - val_loss: 6.7803 - val_categorical_accuracy: 0.2600
# Epoch 00011: early stopping

# %%
plot(history_model3)

# %% [markdown]
# ### Observation : Model3 does not seem to have increase in validation accuracy. It is still overfitting
# #### Since, val_loss did not improve from 1.85, earlystopping stopped at 11/25 epoch

# %% [markdown]
# ## Model #4
# #### Reducing the number of parameters batch_size=20 num_epochs=15 dense_neurons=128 dropout=0.25

# %%
class ModelConv3D4(ModelBuilder):
    
    def define_model(self,dense_neurons=64,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d4=ModelConv3D4()
conv_3d4.initialize_path(project_folder)
conv_3d4.initialize_image_properties(image_height=100,image_width=100)
conv_3d4.initialize_hyperparams(frames_to_sample=16,batch_size=20,num_epochs=15)
conv_3d4_model=conv_3d4.define_model(dense_neurons=128,dropout=0.25)
conv_3d4_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_16 (Conv3D)           (None, 16, 100, 100, 16)  1312
# _________________________________________________________________
# activation_16 (Activation)   (None, 16, 100, 100, 16)  0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 16, 100, 100, 16)  64
# _________________________________________________________________
# max_pooling3d_16 (MaxPooling (None, 8, 50, 50, 16)     0
# _________________________________________________________________
# conv3d_17 (Conv3D)           (None, 8, 50, 50, 32)     4128
# _________________________________________________________________
# activation_17 (Activation)   (None, 8, 50, 50, 32)     0
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 8, 50, 50, 32)     128
# _________________________________________________________________
# max_pooling3d_17 (MaxPooling (None, 4, 25, 25, 32)     0
# _________________________________________________________________
# conv3d_18 (Conv3D)           (None, 4, 25, 25, 64)     16448
# _________________________________________________________________
# activation_18 (Activation)   (None, 4, 25, 25, 64)     0
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 4, 25, 25, 64)     256
# _________________________________________________________________
# max_pooling3d_18 (MaxPooling (None, 2, 12, 12, 64)     0
# _________________________________________________________________
# conv3d_19 (Conv3D)           (None, 2, 12, 12, 128)    65664
# _________________________________________________________________
# activation_19 (Activation)   (None, 2, 12, 12, 128)    0
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 2, 12, 12, 128)    512
# _________________________________________________________________
# max_pooling3d_19 (MaxPooling (None, 1, 6, 6, 128)      0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_12 (Dense)             (None, 128)               589952
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 5)                 645
# =================================================================
# Total params: 696,645
# Trainable params: 695,653
# Non-trainable params: 992
# _________________________________________________________________

# %%
print("Total Params:", conv_3d4_model.count_params())
history_model4=conv_3d4.train_model(conv_3d4_model,augment_data=True)
# Out:
# Total Params: 696645
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/15
# 34/34 [==============================] - ETA: 0s - loss: 1.7140 - categorical_accuracy: 0.3816
# Epoch 00001: val_loss improved from inf to 1.88619, saving model to model_init_2021-08-0207_51_03.839861/model-00001-1.71404-0.38160-1.88619-0.16000.h5
# 34/34 [==============================] - 162s 5s/step - loss: 1.7140 - categorical_accuracy: 0.3816 - val_loss: 1.8862 - val_categorical_accuracy: 0.1600
# Epoch 2/15
# 34/34 [==============================] - ETA: 0s - loss: 1.0263 - categorical_accuracy: 0.6259
# Epoch 00002: val_loss did not improve from 1.88619
# 34/34 [==============================] - 162s 5s/step - loss: 1.0263 - categorical_accuracy: 0.6259 - val_loss: 2.3978 - val_categorical_accuracy: 0.1300
# Epoch 3/15
# 34/34 [==============================] - ETA: 0s - loss: 0.8013 - categorical_accuracy: 0.7081
# Epoch 00003: val_loss did not improve from 1.88619
# 34/34 [==============================] - 159s 5s/step - loss: 0.8013 - categorical_accuracy: 0.7081 - val_loss: 2.9303 - val_categorical_accuracy: 0.1600
# Epoch 4/15
# 34/34 [==============================] - ETA: 0s - loss: 0.7010 - categorical_accuracy: 0.7391
# Epoch 00004: val_loss did not improve from 1.88619
# 34/34 [==============================] - 155s 5s/step - loss: 0.7010 - categorical_accuracy: 0.7391 - val_loss: 3.8953 - val_categorical_accuracy: 0.1400
# Epoch 5/15
# 34/34 [==============================] - ETA: 0s - loss: 0.5818 - categorical_accuracy: 0.7903
# Epoch 00005: val_loss did not improve from 1.88619
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 34/34 [==============================] - 172s 5s/step - loss: 0.5818 - categorical_accuracy: 0.7903 - val_loss: 4.0855 - val_categorical_accuracy: 0.1600
# Epoch 6/15
# 34/34 [==============================] - ETA: 0s - loss: 0.5256 - categorical_accuracy: 0.8175
# Epoch 00006: val_loss did not improve from 1.88619
# 34/34 [==============================] - 176s 5s/step - loss: 0.5256 - categorical_accuracy: 0.8175 - val_loss: 4.1854 - val_categorical_accuracy: 0.1600
# Epoch 7/15
# 34/34 [==============================] - ETA: 0s - loss: 0.4672 - categorical_accuracy: 0.8386
# Epoch 00007: val_loss did not improve from 1.88619
# 34/34 [==============================] - 162s 5s/step - loss: 0.4672 - categorical_accuracy: 0.8386 - val_loss: 4.0835 - val_categorical_accuracy: 0.1600
# Epoch 8/15
# 34/34 [==============================] - ETA: 0s - loss: 0.4887 - categorical_accuracy: 0.8258
# Epoch 00008: val_loss did not improve from 1.88619
# 34/34 [==============================] - 160s 5s/step - loss: 0.4887 - categorical_accuracy: 0.8258 - val_loss: 4.1884 - val_categorical_accuracy: 0.1600
# Epoch 9/15
# 34/34 [==============================] - ETA: 0s - loss: 0.4452 - categorical_accuracy: 0.8333
# Epoch 00009: val_loss did not improve from 1.88619
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 34/34 [==============================] - 155s 5s/step - loss: 0.4452 - categorical_accuracy: 0.8333 - val_loss: 3.7854 - val_categorical_accuracy: 0.2100
# Epoch 10/15
# 34/34 [==============================] - ETA: 0s - loss: 0.4269 - categorical_accuracy: 0.8522
# Epoch 00010: val_loss did not improve from 1.88619
# 34/34 [==============================] - 157s 5s/step - loss: 0.4269 - categorical_accuracy: 0.8522 - val_loss: 3.5631 - val_categorical_accuracy: 0.2500
# Epoch 11/15
# 34/34 [==============================] - ETA: 0s - loss: 0.4463 - categorical_accuracy: 0.8401
# Epoch 00011: val_loss did not improve from 1.88619
# 34/34 [==============================] - 157s 5s/step - loss: 0.4463 - categorical_accuracy: 0.8401 - val_loss: 3.2209 - val_categorical_accuracy: 0.2700
# Epoch 00011: early stopping

# %%
plot(history_model4)

# %% [markdown]
# #### Since, val_loss did not improve from 1.88, earlystopping stopped at 11/25 epoch
# ### Model does not seem to perform well, let's try CNN - LSTM Models

# %% [markdown]
# ## Model #5
# #### CNN- LSTM Model

# %%
from tensorflow.keras.layers import TimeDistributed
from tensorflow.keras.layers import Conv2D, MaxPooling2D, LSTM

# %%
class RNNCNN1(ModelBuilder):
    
    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()

        model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(256, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        model.add(TimeDistributed(Flatten()))


        model.add(LSTM(lstm_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
rnn_cnn1=RNNCNN1()
rnn_cnn1.initialize_path(project_folder)
rnn_cnn1.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn1.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=20)
rnn_cnn1_model=rnn_cnn1.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn1_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 18, 120, 120, 16)  448
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 18, 120, 120, 16)  64
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 18, 60, 60, 16)    0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 18, 60, 60, 32)    4640
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 18, 60, 60, 32)    128
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 18, 30, 30, 32)    0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 18, 30, 30, 64)    18496
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 18, 30, 30, 64)    256
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 18, 15, 15, 64)    0
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 18, 15, 15, 128)   73856
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 18, 15, 15, 128)   512
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 18, 7, 7, 128)     0
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 18, 7, 7, 256)     295168
# _________________________________________________________________
# time_distributed_13 (TimeDis (None, 18, 7, 7, 256)     1024
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 18, 3, 3, 256)     0
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 18, 2304)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 128)               1245696
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_16 (Dense)             (None, 5)                 645
# =================================================================
# Total params: 1,657,445
# Trainable params: 1,656,453
# Non-trainable params: 992
# _________________________________________________________________

# %%
print("Total Params:", rnn_cnn1_model.count_params())
history_model5=rnn_cnn1.train_model(rnn_cnn1_model,augment_data=True)
# Out:
# Total Params: 1657445
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - loss: 1.3208 - categorical_accuracy: 0.4314
# Epoch 00001: val_loss improved from inf to 1.62930, saving model to model_init_2021-08-0208_27_59.817686/model-00001-1.32077-0.43137-1.62930-0.24000.h5
# 34/34 [==============================] - 183s 5s/step - loss: 1.3208 - categorical_accuracy: 0.4314 - val_loss: 1.6293 - val_categorical_accuracy: 0.2400
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 0.9585 - categorical_accuracy: 0.6342
# Epoch 00002: val_loss did not improve from 1.62930
# 34/34 [==============================] - 186s 5s/step - loss: 0.9585 - categorical_accuracy: 0.6342 - val_loss: 2.0118 - val_categorical_accuracy: 0.1900
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7875 - categorical_accuracy: 0.6976
# Epoch 00003: val_loss did not improve from 1.62930
# 34/34 [==============================] - 187s 6s/step - loss: 0.7875 - categorical_accuracy: 0.6976 - val_loss: 1.7736 - val_categorical_accuracy: 0.1600
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7746 - categorical_accuracy: 0.7104
# Epoch 00004: val_loss did not improve from 1.62930
# 34/34 [==============================] - 183s 5s/step - loss: 0.7746 - categorical_accuracy: 0.7104 - val_loss: 1.7376 - val_categorical_accuracy: 0.3900
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - loss: 0.6342 - categorical_accuracy: 0.7662
# Epoch 00005: val_loss did not improve from 1.62930
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 34/34 [==============================] - 182s 5s/step - loss: 0.6342 - categorical_accuracy: 0.7662 - val_loss: 3.3315 - val_categorical_accuracy: 0.2500
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4742 - categorical_accuracy: 0.8228
# Epoch 00006: val_loss did not improve from 1.62930
# 34/34 [==============================] - 177s 5s/step - loss: 0.4742 - categorical_accuracy: 0.8228 - val_loss: 2.3397 - val_categorical_accuracy: 0.3000
# Epoch 7/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3430 - categorical_accuracy: 0.8846
# Epoch 00007: val_loss did not improve from 1.62930
# 34/34 [==============================] - 188s 6s/step - loss: 0.3430 - categorical_accuracy: 0.8846 - val_loss: 2.1121 - val_categorical_accuracy: 0.3800
# Epoch 8/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2975 - categorical_accuracy: 0.8959
# Epoch 00008: val_loss did not improve from 1.62930
# 34/34 [==============================] - 199s 6s/step - loss: 0.2975 - categorical_accuracy: 0.8959 - val_loss: 2.3431 - val_categorical_accuracy: 0.3200
# Epoch 9/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2549 - categorical_accuracy: 0.9163
# Epoch 00009: val_loss did not improve from 1.62930
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 34/34 [==============================] - 193s 6s/step - loss: 0.2549 - categorical_accuracy: 0.9163 - val_loss: 1.9671 - val_categorical_accuracy: 0.4600
# Epoch 10/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2066 - categorical_accuracy: 0.9344
# Epoch 00010: val_loss did not improve from 1.62930
# 34/34 [==============================] - 193s 6s/step - loss: 0.2066 - categorical_accuracy: 0.9344 - val_loss: 2.0818 - val_categorical_accuracy: 0.4700
# Epoch 11/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1996 - categorical_accuracy: 0.9367
# Epoch 00011: val_loss did not improve from 1.62930
# 34/34 [==============================] - 198s 6s/step - loss: 0.1996 - categorical_accuracy: 0.9367 - val_loss: 1.7965 - val_categorical_accuracy: 0.4800
# Epoch 00011: early stopping

# %%
plot(history_model5)

# %% [markdown]
# ### For CNN - LSTM model we get better validation accuracy of 48% so far
# #### As we see more cases of overfitting, lets augment the data with slight rotation as well and run the same models again

# %% [markdown]
# ## Data augmentation & Model Performance

# %%
class ModelBuilderWithAugmentation(metaclass= abc.ABCMeta):
    
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
        
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
          
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx): 
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=resize(image,(self.image_height,self.image_width,3))
            

                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=resize(cropped,(self.image_height,self.image_width,3))
                    
                    M = cv2.getRotationMatrix2D((self.image_width//2,self.image_height//2),
                                                np.random.randint(-10,10), 1.0)
                    rotated = cv2.warpAffine(image_resized, M, (self.image_width, self.image_height))
                    
                    #shifted = cv2.warpAffine(image_resized, 
                    #                        np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                    #                        (image_resized.shape[1], image_resized.shape[0]))
            
                    batch_data_aug[folder,idx,:,:,0] = (rotated[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (rotated[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (rotated[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        callbacks_list = [checkpoint, LR]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

        
    @abc.abstractmethod
    def define_model(self):
        pass

# %%
class Test(ModelBuilderWithAugmentation):
    def define_model(self):
        pass

test_generator=Test()
test_generator.initialize_path(project_folder)
test_generator.initialize_image_properties(image_height=160,image_width=160)
test_generator.initialize_hyperparams(frames_to_sample=30,batch_size=3,num_epochs=1)

g=test_generator.generator(test_generator.val_path,test_generator.val_doc,augment=True)
batch_data, batch_labels=next(g)
fig, axes = plt.subplots(nrows=1, ncols=2)
axes[0].imshow(batch_data[0,29,:,:,:])   
axes[1].imshow(batch_data[3,29,:,:,:])

# %% [markdown]
# ## Model #6 with Augmentation
# #### CNN with GRU

# %%
class RNNCNN2(ModelBuilderWithAugmentation):
    
    def define_model(self,lstm_cells=64,dense_neurons=64,dropout=0.25):

        model = Sequential()

        model.add(TimeDistributed(Conv2D(16, (3, 3) , padding='same', activation='relu'),
                                  input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(32, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(64, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        
        model.add(TimeDistributed(Conv2D(128, (3, 3) , padding='same', activation='relu')))
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        

        model.add(TimeDistributed(Flatten()))


        model.add(GRU(lstm_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
rnn_cnn2=RNNCNN2()
rnn_cnn2.initialize_path(project_folder)
rnn_cnn2.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn2.initialize_hyperparams(frames_to_sample=18,batch_size=20,num_epochs=20)
rnn_cnn2_model=rnn_cnn2.define_model(lstm_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn2_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed (TimeDistri (None, 18, 120, 120, 16)  448
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 18, 120, 120, 16)  64
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 18, 60, 60, 16)    0
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 18, 60, 60, 32)    4640
# _________________________________________________________________
# time_distributed_4 (TimeDist (None, 18, 60, 60, 32)    128
# _________________________________________________________________
# time_distributed_5 (TimeDist (None, 18, 30, 30, 32)    0
# _________________________________________________________________
# time_distributed_6 (TimeDist (None, 18, 30, 30, 64)    18496
# _________________________________________________________________
# time_distributed_7 (TimeDist (None, 18, 30, 30, 64)    256
# _________________________________________________________________
# time_distributed_8 (TimeDist (None, 18, 15, 15, 64)    0
# _________________________________________________________________
# time_distributed_9 (TimeDist (None, 18, 15, 15, 128)   73856
# _________________________________________________________________
# time_distributed_10 (TimeDis (None, 18, 15, 15, 128)   512
# _________________________________________________________________
# time_distributed_11 (TimeDis (None, 18, 7, 7, 128)     0
# _________________________________________________________________
# time_distributed_12 (TimeDis (None, 18, 6272)          0
# _________________________________________________________________
# gru (GRU)                    (None, 128)               2458368
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 2,573,925
# Trainable params: 2,573,445
# Non-trainable params: 480
# _________________________________________________________________

# %%
history_model6=rnn_cnn2.train_model(rnn_cnn2_model,augment_data=True)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# WARNING:tensorflow:From <ipython-input-11-1eecbc45900e>:128: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/20
# 34/34 [==============================] - ETA: 0s - loss: 1.3804 - categorical_accuracy: 0.4276
# Epoch 00001: saving model to model_init_2021-08-0210_08_39.223503/model-00001-1.38041-0.42760-1.63577-0.25000.h5
# 34/34 [==============================] - 215s 6s/step - loss: 1.3804 - categorical_accuracy: 0.4276 - val_loss: 1.6358 - val_categorical_accuracy: 0.2500
# Epoch 2/20
# 34/34 [==============================] - ETA: 0s - loss: 0.9260 - categorical_accuracy: 0.6486
# Epoch 00002: saving model to model_init_2021-08-0210_08_39.223503/model-00002-0.92602-0.64857-1.89347-0.16000.h5
# 34/34 [==============================] - 228s 7s/step - loss: 0.9260 - categorical_accuracy: 0.6486 - val_loss: 1.8935 - val_categorical_accuracy: 0.1600
# Epoch 3/20
# 34/34 [==============================] - ETA: 0s - loss: 0.7114 - categorical_accuracy: 0.7368
# Epoch 00003: saving model to model_init_2021-08-0210_08_39.223503/model-00003-0.71136-0.73680-2.01701-0.27000.h5
# 34/34 [==============================] - 217s 6s/step - loss: 0.7114 - categorical_accuracy: 0.7368 - val_loss: 2.0170 - val_categorical_accuracy: 0.2700
# Epoch 4/20
# 34/34 [==============================] - ETA: 0s - loss: 0.5644 - categorical_accuracy: 0.8009
# Epoch 00004: saving model to model_init_2021-08-0210_08_39.223503/model-00004-0.56442-0.80090-2.58799-0.19000.h5
# 34/34 [==============================] - 215s 6s/step - loss: 0.5644 - categorical_accuracy: 0.8009 - val_loss: 2.5880 - val_categorical_accuracy: 0.1900
# Epoch 5/20
# 34/34 [==============================] - ETA: 0s - loss: 0.4254 - categorical_accuracy: 0.8756
# Epoch 00005: saving model to model_init_2021-08-0210_08_39.223503/model-00005-0.42539-0.87557-2.59453-0.24000.h5
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 34/34 [==============================] - 216s 6s/step - loss: 0.4254 - categorical_accuracy: 0.8756 - val_loss: 2.5945 - val_categorical_accuracy: 0.2400
# Epoch 6/20
# 34/34 [==============================] - ETA: 0s - loss: 0.3409 - categorical_accuracy: 0.8967
# Epoch 00006: saving model to model_init_2021-08-0210_08_39.223503/model-00006-0.34086-0.89668-2.73324-0.21000.h5
# 34/34 [==============================] - 219s 6s/step - loss: 0.3409 - categorical_accuracy: 0.8967 - val_loss: 2.7332 - val_categorical_accuracy: 0.2100
# Epoch 7/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2804 - categorical_accuracy: 0.9216
# Epoch 00007: saving model to model_init_2021-08-0210_08_39.223503/model-00007-0.28037-0.92157-2.79863-0.20000.h5
# 34/34 [==============================] - 223s 7s/step - loss: 0.2804 - categorical_accuracy: 0.9216 - val_loss: 2.7986 - val_categorical_accuracy: 0.2000
# Epoch 8/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2749 - categorical_accuracy: 0.9216
# Epoch 00008: saving model to model_init_2021-08-0210_08_39.223503/model-00008-0.27489-0.92157-2.91963-0.29000.h5
# 34/34 [==============================] - 226s 7s/step - loss: 0.2749 - categorical_accuracy: 0.9216 - val_loss: 2.9196 - val_categorical_accuracy: 0.2900
# Epoch 9/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2570 - categorical_accuracy: 0.9382
# Epoch 00009: saving model to model_init_2021-08-0210_08_39.223503/model-00009-0.25705-0.93816-2.90707-0.25000.h5
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 7.999999797903002e-06.
# 34/34 [==============================] - 220s 6s/step - loss: 0.2570 - categorical_accuracy: 0.9382 - val_loss: 2.9071 - val_categorical_accuracy: 0.2500
# Epoch 10/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2382 - categorical_accuracy: 0.9419
# Epoch 00010: saving model to model_init_2021-08-0210_08_39.223503/model-00010-0.23817-0.94193-2.51944-0.31000.h5
# 34/34 [==============================] - 221s 7s/step - loss: 0.2382 - categorical_accuracy: 0.9419 - val_loss: 2.5194 - val_categorical_accuracy: 0.3100
# Epoch 11/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2228 - categorical_accuracy: 0.9397
# Epoch 00011: saving model to model_init_2021-08-0210_08_39.223503/model-00011-0.22277-0.93967-2.23225-0.37000.h5
# 34/34 [==============================] - 216s 6s/step - loss: 0.2228 - categorical_accuracy: 0.9397 - val_loss: 2.2323 - val_categorical_accuracy: 0.3700
# Epoch 12/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2318 - categorical_accuracy: 0.9389
# Epoch 00012: saving model to model_init_2021-08-0210_08_39.223503/model-00012-0.23182-0.93891-2.09636-0.40000.h5
# 34/34 [==============================] - 225s 7s/step - loss: 0.2318 - categorical_accuracy: 0.9389 - val_loss: 2.0964 - val_categorical_accuracy: 0.4000
# Epoch 13/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2130 - categorical_accuracy: 0.9517
# Epoch 00013: saving model to model_init_2021-08-0210_08_39.223503/model-00013-0.21302-0.95173-1.47975-0.50000.h5
# 34/34 [==============================] - 219s 6s/step - loss: 0.2130 - categorical_accuracy: 0.9517 - val_loss: 1.4798 - val_categorical_accuracy: 0.5000
# Epoch 14/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2191 - categorical_accuracy: 0.9495
# Epoch 00014: saving model to model_init_2021-08-0210_08_39.223503/model-00014-0.21915-0.94947-1.13586-0.57000.h5
# 34/34 [==============================] - 214s 6s/step - loss: 0.2191 - categorical_accuracy: 0.9495 - val_loss: 1.1359 - val_categorical_accuracy: 0.5700
# Epoch 15/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2034 - categorical_accuracy: 0.9548
# Epoch 00015: saving model to model_init_2021-08-0210_08_39.223503/model-00015-0.20344-0.95475-1.50197-0.52000.h5
# 34/34 [==============================] - 212s 6s/step - loss: 0.2034 - categorical_accuracy: 0.9548 - val_loss: 1.5020 - val_categorical_accuracy: 0.5200
# Epoch 16/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1958 - categorical_accuracy: 0.9480
# Epoch 00016: saving model to model_init_2021-08-0210_08_39.223503/model-00016-0.19575-0.94796-0.99255-0.67000.h5
# 34/34 [==============================] - 189s 6s/step - loss: 0.1958 - categorical_accuracy: 0.9480 - val_loss: 0.9925 - val_categorical_accuracy: 0.6700
# Epoch 17/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2028 - categorical_accuracy: 0.9563
# Epoch 00017: saving model to model_init_2021-08-0210_08_39.223503/model-00017-0.20283-0.95626-0.90224-0.68000.h5
# 34/34 [==============================] - 184s 5s/step - loss: 0.2028 - categorical_accuracy: 0.9563 - val_loss: 0.9022 - val_categorical_accuracy: 0.6800
# Epoch 18/20
# 34/34 [==============================] - ETA: 0s - loss: 0.2011 - categorical_accuracy: 0.9487
# Epoch 00018: saving model to model_init_2021-08-0210_08_39.223503/model-00018-0.20113-0.94872-0.76859-0.73000.h5
# 34/34 [==============================] - 182s 5s/step - loss: 0.2011 - categorical_accuracy: 0.9487 - val_loss: 0.7686 - val_categorical_accuracy: 0.7300
# Epoch 19/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1949 - categorical_accuracy: 0.9540
# Epoch 00019: saving model to model_init_2021-08-0210_08_39.223503/model-00019-0.19490-0.95400-0.60650-0.81000.h5
# 34/34 [==============================] - 198s 6s/step - loss: 0.1949 - categorical_accuracy: 0.9540 - val_loss: 0.6065 - val_categorical_accuracy: 0.8100
# Epoch 20/20
# 34/34 [==============================] - ETA: 0s - loss: 0.1910 - categorical_accuracy: 0.9555
# Epoch 00020: saving model to model_init_2021-08-0210_08_39.223503/model-00020-0.19101-0.95551-0.66546-0.78000.h5
# 34/34 [==============================] - 219s 6s/step - loss: 0.1910 - categorical_accuracy: 0.9555 - val_loss: 0.6655 - val_categorical_accuracy: 0.7800

# %%
plot(history_model6)

# %% [markdown]
# ### We see that overfitting is still there after doing augmentation. However, there is significant improvement on accuracy with 78% on validation data

# %% [markdown]
# ## Model #7
# #### Using Transfer Learning (Mobilenet Model) with GRU

# %%
from tensorflow.keras.applications import mobilenet

mobilenet_transfer = mobilenet.MobileNet(weights='imagenet', include_top=False)

class RNNCNN_TL2(ModelBuilderWithAugmentation):
    
    def define_model(self,gru_cells=64,dense_neurons=64,dropout=0.25):
        
        model = Sequential()
        model.add(TimeDistributed(mobilenet_transfer,input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
 
        
        model.add(TimeDistributed(BatchNormalization()))
        model.add(TimeDistributed(MaxPooling2D((2, 2))))
        model.add(TimeDistributed(Flatten()))

        model.add(GRU(gru_cells))
        model.add(Dropout(dropout))
        
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(Dropout(dropout))
        
        model.add(Dense(self.num_classes, activation='softmax'))
        
        
        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.

# %%
rnn_cnn_tl2=RNNCNN_TL2()
rnn_cnn_tl2.initialize_path(project_folder)
rnn_cnn_tl2.initialize_image_properties(image_height=120,image_width=120)
rnn_cnn_tl2.initialize_hyperparams(frames_to_sample=16,batch_size=5,num_epochs=20)
rnn_cnn_tl2_model=rnn_cnn_tl2.define_model(gru_cells=128,dense_neurons=128,dropout=0.25)
rnn_cnn_tl2_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# time_distributed_13 (TimeDis (None, 16, 3, 3, 1024)    3228864
# _________________________________________________________________
# time_distributed_14 (TimeDis (None, 16, 3, 3, 1024)    4096
# _________________________________________________________________
# time_distributed_15 (TimeDis (None, 16, 1, 1, 1024)    0
# _________________________________________________________________
# time_distributed_16 (TimeDis (None, 16, 1024)          0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 128)               443136
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 3,693,253
# Trainable params: 3,669,317
# Non-trainable params: 23,936
# _________________________________________________________________

# %%
history_model7=rnn_cnn_tl2.train_model(rnn_cnn_tl2_model,augment_data=True)
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/20
# 133/133 [==============================] - ETA: 0s - loss: 0.8824 - categorical_accuracy: 0.6697
# Epoch 00001: saving model to model_init_2021-08-0211_28_58.592656/model-00001-0.88236-0.66968-0.48750-0.83000.h5
# 133/133 [==============================] - 184s 1s/step - loss: 0.8824 - categorical_accuracy: 0.6697 - val_loss: 0.4875 - val_categorical_accuracy: 0.8300
# Epoch 2/20
# 133/133 [==============================] - ETA: 0s - loss: 0.4610 - categorical_accuracy: 0.8529
# Epoch 00002: saving model to model_init_2021-08-0211_28_58.592656/model-00002-0.46098-0.85294-0.42170-0.86000.h5
# 133/133 [==============================] - 187s 1s/step - loss: 0.4610 - categorical_accuracy: 0.8529 - val_loss: 0.4217 - val_categorical_accuracy: 0.8600
# Epoch 3/20
# 133/133 [==============================] - ETA: 0s - loss: 0.2347 - categorical_accuracy: 0.9314
# Epoch 00003: saving model to model_init_2021-08-0211_28_58.592656/model-00003-0.23475-0.93137-0.42227-0.84000.h5
# 133/133 [==============================] - 197s 1s/step - loss: 0.2347 - categorical_accuracy: 0.9314 - val_loss: 0.4223 - val_categorical_accuracy: 0.8400
# Epoch 4/20
# 133/133 [==============================] - ETA: 0s - loss: 0.2110 - categorical_accuracy: 0.9389
# Epoch 00004: saving model to model_init_2021-08-0211_28_58.592656/model-00004-0.21101-0.93891-0.15133-0.94000.h5
# 133/133 [==============================] - 190s 1s/step - loss: 0.2110 - categorical_accuracy: 0.9389 - val_loss: 0.1513 - val_categorical_accuracy: 0.9400
# Epoch 5/20
# 133/133 [==============================] - ETA: 0s - loss: 0.1701 - categorical_accuracy: 0.9502
# Epoch 00005: saving model to model_init_2021-08-0211_28_58.592656/model-00005-0.17010-0.95023-0.15616-0.95000.h5
# 133/133 [==============================] - 193s 1s/step - loss: 0.1701 - categorical_accuracy: 0.9502 - val_loss: 0.1562 - val_categorical_accuracy: 0.9500
# Epoch 6/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0879 - categorical_accuracy: 0.9683
# Epoch 00006: saving model to model_init_2021-08-0211_28_58.592656/model-00006-0.08788-0.96833-0.23250-0.92000.h5
# 133/133 [==============================] - 199s 1s/step - loss: 0.0879 - categorical_accuracy: 0.9683 - val_loss: 0.2325 - val_categorical_accuracy: 0.9200
# Epoch 7/20
# 133/133 [==============================] - ETA: 0s - loss: 0.1356 - categorical_accuracy: 0.9593
# Epoch 00007: saving model to model_init_2021-08-0211_28_58.592656/model-00007-0.13558-0.95928-0.10488-0.98000.h5
# 133/133 [==============================] - 194s 1s/step - loss: 0.1356 - categorical_accuracy: 0.9593 - val_loss: 0.1049 - val_categorical_accuracy: 0.9800
# Epoch 8/20
# 133/133 [==============================] - ETA: 0s - loss: 0.1211 - categorical_accuracy: 0.9593
# Epoch 00008: saving model to model_init_2021-08-0211_28_58.592656/model-00008-0.12107-0.95928-0.07078-0.97000.h5
# 133/133 [==============================] - 178s 1s/step - loss: 0.1211 - categorical_accuracy: 0.9593 - val_loss: 0.0708 - val_categorical_accuracy: 0.9700
# Epoch 9/20
# 133/133 [==============================] - ETA: 0s - loss: 0.1406 - categorical_accuracy: 0.9608
# Epoch 00009: saving model to model_init_2021-08-0211_28_58.592656/model-00009-0.14061-0.96078-0.18827-0.96000.h5
# 133/133 [==============================] - 181s 1s/step - loss: 0.1406 - categorical_accuracy: 0.9608 - val_loss: 0.1883 - val_categorical_accuracy: 0.9600
# Epoch 10/20
# 133/133 [==============================] - ETA: 0s - loss: 0.1044 - categorical_accuracy: 0.9653
# Epoch 00010: saving model to model_init_2021-08-0211_28_58.592656/model-00010-0.10441-0.96531-0.09994-0.95000.h5
# 133/133 [==============================] - 181s 1s/step - loss: 0.1044 - categorical_accuracy: 0.9653 - val_loss: 0.0999 - val_categorical_accuracy: 0.9500
# Epoch 11/20
# 133/133 [==============================] - ETA: 0s - loss: 0.1157 - categorical_accuracy: 0.9691
# Epoch 00011: saving model to model_init_2021-08-0211_28_58.592656/model-00011-0.11574-0.96908-0.18067-0.96000.h5
# 133/133 [==============================] - 180s 1s/step - loss: 0.1157 - categorical_accuracy: 0.9691 - val_loss: 0.1807 - val_categorical_accuracy: 0.9600
# Epoch 12/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0987 - categorical_accuracy: 0.9691
# Epoch 00012: saving model to model_init_2021-08-0211_28_58.592656/model-00012-0.09869-0.96908-0.07905-0.98000.h5
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 133/133 [==============================] - 181s 1s/step - loss: 0.0987 - categorical_accuracy: 0.9691 - val_loss: 0.0790 - val_categorical_accuracy: 0.9800
# Epoch 13/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0388 - categorical_accuracy: 0.9902
# Epoch 00013: saving model to model_init_2021-08-0211_28_58.592656/model-00013-0.03884-0.99020-0.03752-0.98000.h5
# 133/133 [==============================] - 164s 1s/step - loss: 0.0388 - categorical_accuracy: 0.9902 - val_loss: 0.0375 - val_categorical_accuracy: 0.9800
# Epoch 14/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0357 - categorical_accuracy: 0.9887
# Epoch 00014: saving model to model_init_2021-08-0211_28_58.592656/model-00014-0.03573-0.98869-0.00887-1.00000.h5
# 133/133 [==============================] - 181s 1s/step - loss: 0.0357 - categorical_accuracy: 0.9887 - val_loss: 0.0089 - val_categorical_accuracy: 1.0000
# Epoch 15/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0205 - categorical_accuracy: 0.9932
# Epoch 00015: saving model to model_init_2021-08-0211_28_58.592656/model-00015-0.02046-0.99321-0.02264-0.98000.h5
# 133/133 [==============================] - 179s 1s/step - loss: 0.0205 - categorical_accuracy: 0.9932 - val_loss: 0.0226 - val_categorical_accuracy: 0.9800
# Epoch 16/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0172 - categorical_accuracy: 0.9955
# Epoch 00016: saving model to model_init_2021-08-0211_28_58.592656/model-00016-0.01719-0.99548-0.01608-0.99000.h5
# 133/133 [==============================] - 188s 1s/step - loss: 0.0172 - categorical_accuracy: 0.9955 - val_loss: 0.0161 - val_categorical_accuracy: 0.9900
# Epoch 17/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0113 - categorical_accuracy: 0.9962
# Epoch 00017: saving model to model_init_2021-08-0211_28_58.592656/model-00017-0.01128-0.99623-0.00367-1.00000.h5
# 133/133 [==============================] - 176s 1s/step - loss: 0.0113 - categorical_accuracy: 0.9962 - val_loss: 0.0037 - val_categorical_accuracy: 1.0000
# Epoch 18/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0106 - categorical_accuracy: 0.9962
# Epoch 00018: saving model to model_init_2021-08-0211_28_58.592656/model-00018-0.01060-0.99623-0.02705-0.98000.h5
# 133/133 [==============================] - 185s 1s/step - loss: 0.0106 - categorical_accuracy: 0.9962 - val_loss: 0.0271 - val_categorical_accuracy: 0.9800
# Epoch 19/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0072 - categorical_accuracy: 0.9977
# Epoch 00019: saving model to model_init_2021-08-0211_28_58.592656/model-00019-0.00719-0.99774-0.01558-0.99000.h5
# 133/133 [==============================] - 178s 1s/step - loss: 0.0072 - categorical_accuracy: 0.9977 - val_loss: 0.0156 - val_categorical_accuracy: 0.9900
# Epoch 20/20
# 133/133 [==============================] - ETA: 0s - loss: 0.0184 - categorical_accuracy: 0.9962
# Epoch 00020: saving model to model_init_2021-08-0211_28_58.592656/model-00020-0.01843-0.99623-0.02503-0.99000.h5
# 133/133 [==============================] - 186s 1s/step - loss: 0.0184 - categorical_accuracy: 0.9962 - val_loss: 0.0250 - val_categorical_accuracy: 0.9900

# %%
plot(history_model7)

# %% [markdown]
# #### 7th Model gives the best results!
# #### 99.63% Training accuracy and 99.00% validation accuracy

# %% [markdown]
# ## Saving & Loading model
# #### Since the last model Transfer learning with GRU gave us the best results, we proceed to save this further as "Final_best_model.h5"

# %%
#Importing h5py
# !pip install h5py
#Saving final model as "Final_best_model.h5"
rnn_cnn_tl2_model.save("Final_best_model.h5")
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.17.3)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# WARNING: You are using pip version 20.2.4; however, version 21.2.1 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.
